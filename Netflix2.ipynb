# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv ('../../../DATA/IPL Matches 2008-2020.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df['date'] = pd.to_datetime(df.date)

# %%
city_name = df.groupby (by='city')

# %%
city_an = df.groupby (by='city')

# %%
city_ch = city_name.get_group ('Mumbai')

# %%
for item in list(city_ch.team2.value_counts().index):
    if(item not in list(city_ch.team1.value_counts().index)):
# Out:
# Kings XI Punjab
# Kolkata Knight Riders
# Gujarat Lions
# Kochi Tuskers Kerala
# Rising Pune Supergiant
# Rising Pune Supergiants
# Delhi Capitals

# %%
l = list (city_ch.team2.value_counts().values)
plt.style.use ('seaborn')
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols = 1)
ax1.set_title ('Team1')
ax1.barh (list(city_ch.team1.value_counts().index), list (city_ch.team1.value_counts().values))
ax2.set_title ('Team2')
ax2.pie (l[:6], labels = list(city_ch.team2.value_counts().index)[:6], autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1f32c0493d0>,
# ...
#  [Text(0.9180305717987314, 0.6059866906483133, 'Kings XI Punjab'),
#   Text(-0.1964126233646067, 1.0823225403654095, 'Kolkata Knight Riders'),
#   Text(-1.060359165161897, 0.2926404634652645, 'Chennai Super Kings'),
#   Text(-0.795074278021232, -0.7601689893892126, 'Rajasthan Royals'),
#   Text(0.19641272469895568, -1.0823225219759276, 'Delhi Daredevils'),
#   Text(0.991065834488076, -0.4772719473323923, 'Royal Challengers Bangalore')],
#  [Text(0.5007439482538535, 0.33053819489907993, '18.57%'),
#   Text(-0.10713415819887637, 0.5903577492902233, '18.57%'),
#   Text(-0.5783777264519439, 0.15962207098105335, '17.14%'),
#   Text(-0.4336768789206719, -0.4146376305759341, '15.71%'),
#   Text(0.10713421347215764, -0.5903577392595968, '15.71%'),
#   Text(0.5405813642662232, -0.2603301530903958, '14.29%')])
